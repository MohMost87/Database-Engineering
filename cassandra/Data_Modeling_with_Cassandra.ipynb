# %% [markdown]
# <a href="https://colab.research.google.com/github/MohMost87/Database-Systems/blob/main/Data_Modeling_with_Cassandra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ETL FOR PREPROCESSING FILES OF DATA**

# %% [markdown]
# import packages required for preprocessing data
# install casandra driver

# %%
# !pip install cassandra-driver
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 35.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv
